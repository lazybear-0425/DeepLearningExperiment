# %% [markdown]
#  - L1 & L2 的差別
#     - [LINK](https://discuss.pytorch.org/t/how-is-your-experience-of-using-l1-regularization/153565)
#  - 注意tensor和scalar<font color=yellow>不要混用</font>
#  - 備註
#     - 我沒有切Validation

# %%
from torch import nn
from torchvision.datasets import FashionMNIST
from torch.utils.data import DataLoader
from torch.optim import Adam
from torchvision.transforms import ToTensor, Compose
from torch.nn import CrossEntropyLoss
import torch
from torch.nn.functional import one_hot
import numpy as np
import matplotlib.pyplot as plt

# %%
# hyper-parameter
batch_size = 256
epochs = 100
lambd = 0.001
reg = 'L2' # None, 'L1', 'L2'

# %%
train_data = FashionMNIST('data', train=True, transform=ToTensor()
                          , download=True)
test_data = FashionMNIST('data', train=False, transform=ToTensor()
                          , download=True)

train_loader = DataLoader(train_data, batch_size=batch_size)
test_loader = DataLoader(test_data, batch_size=batch_size)

# %%
class Module(nn.Module):
    def __init__(self):
        super(Module, self).__init__()
        self.net = nn.Sequential(
            nn.Flatten(), 
            nn.LazyLinear(10)
        )
    def forward(self, X):
        return self.net(X)

# %%
model = Module()
optimizer = Adam(model.parameters(), lr=0.003)
loss = CrossEntropyLoss()

# %%
history = {'acc':[], 'val_acc':[], 'loss':[], 'val_loss':[]}
for i in range(epochs):
    print(f'==== Epoch {i + 1} start! ============================')
    model.train()
    training_acc = 0
    training_loss = 0
    for data in train_loader:
        optimizer.zero_grad()
        img, label = data
        output = model(img)
        output_loss = loss(output, label.long())
        # record
        training_loss = training_loss + output_loss.item() # 因為原本是tensor
        training_acc = training_acc + (output.argmax(dim=1) == label).sum().item() # 原本是tensor
        # Regularization
        reg_loss = torch.tensor(0, dtype=torch.float32)
        if reg == 'L1': # L1 Norm
            reg_loss = lambd * sum(param.norm(1) for param in model.parameters())
        elif reg == 'L2': # L2 Norm
            reg_loss = lambd * sum(param.norm(2) for param in model.parameters())
        output_loss = output_loss + reg_loss.detach()
        print('*', reg_loss)
        
        if reg == 'L1':
            l1_norm = sum(p.abs().sum() for p in model.parameters())
            output_loss += lambd * l1_norm
            
            # Apply L2 regularization
        elif reg == 'L2':
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            output_loss += lambd * l2_norm
            for p in model.parameters():
                print(p.norm(2))
                print(p.pow(2).sum() / len(p))
                print('===')
            print()

        # BP
        output_loss.backward()
        optimizer.step()
    history['loss'].append(training_loss / len(train_data))
    history['acc'].append(training_acc / len(train_data))
    model.eval()
    test_acc = 0
    test_loss = 0
    with torch.no_grad():
        for data in test_loader:
            img, label = data
            output = model(img)
            test_acc = test_acc + (output.argmax(dim=1) == label).sum().item()
            test_loss = test_loss + loss(output, label).item()
    history['val_acc'].append(test_acc / len(test_data))
    history['val_loss'].append(test_loss / len(test_data))
    print(f'Training Accuracy {training_acc / len(train_data):.4f}, training loss: {training_loss / len(train_data):.4f}')
    print(f'Test Accuracy: {test_acc / len(test_data):.4f}, test loss: {test_loss / len(test_data):.4f}')
    print('===================== End ========================')
    print()
# Out:
# ==== Epoch 1 start! ============================
# * tensor(0.0019, grad_fn=<MulBackward0>)
# tensor(1.8345, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.3365, grad_fn=<DivBackward0>)
# ===
# tensor(0.0573, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0003, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0019, grad_fn=<MulBackward0>)
# tensor(1.8469, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.3411, grad_fn=<DivBackward0>)
# ===
# tensor(0.0557, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0003, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0019, grad_fn=<MulBackward0>)
# tensor(1.8796, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.3533, grad_fn=<DivBackward0>)
# ===
# tensor(0.0577, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0003, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0020, grad_fn=<MulBackward0>)
# tensor(1.9291, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.3721, grad_fn=<DivBackward0>)
# ===
# tensor(0.0594, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0004, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0021, grad_fn=<MulBackward0>)
# tensor(1.9911, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.3964, grad_fn=<DivBackward0>)
# ===
# tensor(0.0612, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0004, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0021, grad_fn=<MulBackward0>)
# tensor(2.0643, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.4261, grad_fn=<DivBackward0>)
# ===
# tensor(0.0644, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0004, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0022, grad_fn=<MulBackward0>)
# tensor(2.1466, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.4608, grad_fn=<DivBackward0>)
# ===
# tensor(0.0679, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0005, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0023, grad_fn=<MulBackward0>)
# tensor(2.2364, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.5001, grad_fn=<DivBackward0>)
# ===
# tensor(0.0713, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0005, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0024, grad_fn=<MulBackward0>)
# tensor(2.3304, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.5431, grad_fn=<DivBackward0>)
# ===
# tensor(0.0746, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0006, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0025, grad_fn=<MulBackward0>)
# tensor(2.4274, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.5892, grad_fn=<DivBackward0>)
# ===
# tensor(0.0776, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0006, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0026, grad_fn=<MulBackward0>)
# tensor(2.5255, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.6378, grad_fn=<DivBackward0>)
# ===
# tensor(0.0803, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0006, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0027, grad_fn=<MulBackward0>)
# tensor(2.6241, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.6886, grad_fn=<DivBackward0>)
# ===
# tensor(0.0831, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0007, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0028, grad_fn=<MulBackward0>)
# tensor(2.7205, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.7401, grad_fn=<DivBackward0>)
# ===
# tensor(0.0858, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0007, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0029, grad_fn=<MulBackward0>)
# tensor(2.8149, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.7924, grad_fn=<DivBackward0>)
# ===
# tensor(0.0886, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0008, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0030, grad_fn=<MulBackward0>)
# tensor(2.9065, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.8448, grad_fn=<DivBackward0>)
# ===
# tensor(0.0912, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0008, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0031, grad_fn=<MulBackward0>)
# tensor(2.9951, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.8971, grad_fn=<DivBackward0>)
# ===
# tensor(0.0938, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0009, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0032, grad_fn=<MulBackward0>)
# tensor(3.0788, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.9479, grad_fn=<DivBackward0>)
# ===
# tensor(0.0964, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0009, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0033, grad_fn=<MulBackward0>)
# tensor(3.1594, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.9982, grad_fn=<DivBackward0>)
# ===
# tensor(0.0992, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0010, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0033, grad_fn=<MulBackward0>)
# tensor(3.2372, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.0480, grad_fn=<DivBackward0>)
# ===
# tensor(0.1018, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0010, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0034, grad_fn=<MulBackward0>)
# tensor(3.3114, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.0965, grad_fn=<DivBackward0>)
# ===
# tensor(0.1043, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0011, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0035, grad_fn=<MulBackward0>)
# tensor(3.3823, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.1440, grad_fn=<DivBackward0>)
# ===
# tensor(0.1069, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0011, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0036, grad_fn=<MulBackward0>)
# tensor(3.4490, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.1896, grad_fn=<DivBackward0>)
# ===
# tensor(0.1093, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0012, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0036, grad_fn=<MulBackward0>)
# tensor(3.5120, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.2334, grad_fn=<DivBackward0>)
# ===
# tensor(0.1117, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0012, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0037, grad_fn=<MulBackward0>)
# tensor(3.5716, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.2756, grad_fn=<DivBackward0>)
# ===
# tensor(0.1144, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0013, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0037, grad_fn=<MulBackward0>)
# tensor(3.6286, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.3167, grad_fn=<DivBackward0>)
# ===
# tensor(0.1169, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0014, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0038, grad_fn=<MulBackward0>)
# tensor(3.6826, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.3561, grad_fn=<DivBackward0>)
# ===
# tensor(0.1195, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0014, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0039, grad_fn=<MulBackward0>)
# tensor(3.7324, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.3931, grad_fn=<DivBackward0>)
# ===
# tensor(0.1222, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0015, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0039, grad_fn=<MulBackward0>)
# tensor(3.7799, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.4288, grad_fn=<DivBackward0>)
# ===
# tensor(0.1250, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0016, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0040, grad_fn=<MulBackward0>)
# tensor(3.8246, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.4627, grad_fn=<DivBackward0>)
# ===
# tensor(0.1277, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0016, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0040, grad_fn=<MulBackward0>)
# tensor(3.8671, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.4955, grad_fn=<DivBackward0>)
# ===
# tensor(0.1305, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0017, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0040, grad_fn=<MulBackward0>)
# tensor(3.9069, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.5264, grad_fn=<DivBackward0>)
# ===
# tensor(0.1333, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0018, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0041, grad_fn=<MulBackward0>)
# tensor(3.9440, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.5555, grad_fn=<DivBackward0>)
# ===
# tensor(0.1360, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0018, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0041, grad_fn=<MulBackward0>)
# tensor(3.9799, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.5840, grad_fn=<DivBackward0>)
# ===
# tensor(0.1385, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0019, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0042, grad_fn=<MulBackward0>)
# tensor(4.0150, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.6120, grad_fn=<DivBackward0>)
# ===
# tensor(0.1408, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0020, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0042, grad_fn=<MulBackward0>)
# tensor(4.0492, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.6396, grad_fn=<DivBackward0>)
# ===
# tensor(0.1429, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0020, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0042, grad_fn=<MulBackward0>)
# tensor(4.0821, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.6663, grad_fn=<DivBackward0>)
# ===
# tensor(0.1449, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0021, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0043, grad_fn=<MulBackward0>)
# tensor(4.1148, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.6932, grad_fn=<DivBackward0>)
# ===
# tensor(0.1467, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0022, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0043, grad_fn=<MulBackward0>)
# tensor(4.1459, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.7189, grad_fn=<DivBackward0>)
# ===
# tensor(0.1487, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0022, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0043, grad_fn=<MulBackward0>)
# tensor(4.1746, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.7427, grad_fn=<DivBackward0>)
# ===
# tensor(0.1509, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0023, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0044, grad_fn=<MulBackward0>)
# tensor(4.2019, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.7656, grad_fn=<DivBackward0>)
# ===
# tensor(0.1533, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0024, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0044, grad_fn=<MulBackward0>)
# tensor(4.2281, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.7877, grad_fn=<DivBackward0>)
# ===
# tensor(0.1559, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0024, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0044, grad_fn=<MulBackward0>)
# tensor(4.2535, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.8093, grad_fn=<DivBackward0>)
# ===
# tensor(0.1586, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0025, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0044, grad_fn=<MulBackward0>)
# tensor(4.2778, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.8300, grad_fn=<DivBackward0>)
# ===
# tensor(0.1611, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0026, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0045, grad_fn=<MulBackward0>)
# tensor(4.3017, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.8505, grad_fn=<DivBackward0>)
# ===
# tensor(0.1632, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0027, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0045, grad_fn=<MulBackward0>)
# tensor(4.3247, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.8703, grad_fn=<DivBackward0>)
# ===
# tensor(0.1650, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0027, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0045, grad_fn=<MulBackward0>)
# tensor(4.3473, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.8899, grad_fn=<DivBackward0>)
# ===
# tensor(0.1667, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0028, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0045, grad_fn=<MulBackward0>)
# tensor(4.3697, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.9094, grad_fn=<DivBackward0>)
# ===
# tensor(0.1685, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0028, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0046, grad_fn=<MulBackward0>)
# tensor(4.3920, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.9290, grad_fn=<DivBackward0>)
# ===
# tensor(0.1704, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0029, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0046, grad_fn=<MulBackward0>)
# tensor(4.4147, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.9489, grad_fn=<DivBackward0>)
# ===
# tensor(0.1726, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0030, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0046, grad_fn=<MulBackward0>)
# tensor(4.4366, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.9683, grad_fn=<DivBackward0>)
# ===
# tensor(0.1749, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0031, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0046, grad_fn=<MulBackward0>)
# tensor(4.4578, grad_fn=<LinalgVectorNormBackward0>)
# tensor(1.9872, grad_fn=<DivBackward0>)
# ===
# tensor(0.1771, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0031, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0047, grad_fn=<MulBackward0>)
# tensor(4.4784, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.0056, grad_fn=<DivBackward0>)
# ===
# tensor(0.1794, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0032, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0047, grad_fn=<MulBackward0>)
# tensor(4.4983, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.0234, grad_fn=<DivBackward0>)
# ===
# tensor(0.1818, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0033, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0047, grad_fn=<MulBackward0>)
# tensor(4.5177, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.0409, grad_fn=<DivBackward0>)
# ===
# tensor(0.1840, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0034, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0047, grad_fn=<MulBackward0>)
# tensor(4.5361, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.0576, grad_fn=<DivBackward0>)
# ===
# tensor(0.1861, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0035, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0047, grad_fn=<MulBackward0>)
# tensor(4.5545, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.0744, grad_fn=<DivBackward0>)
# ===
# tensor(0.1881, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0035, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0048, grad_fn=<MulBackward0>)
# tensor(4.5728, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.0911, grad_fn=<DivBackward0>)
# ===
# tensor(0.1901, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0036, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0048, grad_fn=<MulBackward0>)
# tensor(4.5905, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.1073, grad_fn=<DivBackward0>)
# ===
# tensor(0.1922, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0037, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0048, grad_fn=<MulBackward0>)
# tensor(4.6077, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.1231, grad_fn=<DivBackward0>)
# ===
# tensor(0.1943, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0038, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0048, grad_fn=<MulBackward0>)
# tensor(4.6247, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.1388, grad_fn=<DivBackward0>)
# ===
# tensor(0.1964, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0039, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0048, grad_fn=<MulBackward0>)
# tensor(4.6417, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.1545, grad_fn=<DivBackward0>)
# ===
# tensor(0.1987, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0039, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0049, grad_fn=<MulBackward0>)
# tensor(4.6578, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.1695, grad_fn=<DivBackward0>)
# ===
# tensor(0.2011, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0040, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0049, grad_fn=<MulBackward0>)
# tensor(4.6740, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.1847, grad_fn=<DivBackward0>)
# ===
# tensor(0.2035, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0041, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0049, grad_fn=<MulBackward0>)
# tensor(4.6901, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.1997, grad_fn=<DivBackward0>)
# ===
# tensor(0.2058, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0042, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0049, grad_fn=<MulBackward0>)
# tensor(4.7059, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.2146, grad_fn=<DivBackward0>)
# ===
# tensor(0.2081, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0043, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0049, grad_fn=<MulBackward0>)
# tensor(4.7213, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.2291, grad_fn=<DivBackward0>)
# ===
# tensor(0.2105, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0044, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0049, grad_fn=<MulBackward0>)
# tensor(4.7364, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.2433, grad_fn=<DivBackward0>)
# ===
# tensor(0.2127, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0045, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0050, grad_fn=<MulBackward0>)
# tensor(4.7526, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.2587, grad_fn=<DivBackward0>)
# ===
# tensor(0.2147, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0046, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0050, grad_fn=<MulBackward0>)
# tensor(4.7685, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.2739, grad_fn=<DivBackward0>)
# ===
# tensor(0.2168, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0047, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0050, grad_fn=<MulBackward0>)
# tensor(4.7846, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.2893, grad_fn=<DivBackward0>)
# ===
# tensor(0.2190, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0048, grad_fn=<DivBackward0>)
# ===
#
# * tensor(0.0050, grad_fn=<MulBackward0>)
# tensor(4.7997, grad_fn=<LinalgVectorNormBackward0>)
# tensor(2.3037, grad_fn=<DivBackward0>)
# ===
# tensor(0.2212, grad_fn=<LinalgVectorNormBackward0>)
# tensor(0.0049, grad_fn=<DivBackward0>)
# ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 7
#       5 training_acc = 0
#       6 training_loss = 0
# ----> 7 for data in train_loader:
#       8     optimizer.zero_grad()
#       9     img, label = data
#
# File d:\Anaconda\lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File d:\Anaconda\lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File d:\Anaconda\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File d:\Anaconda\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File d:\Anaconda\lib\site-packages\torchvision\datasets\mnist.py:146, in MNIST.__getitem__(self, index)
#     143 img = Image.fromarray(img.numpy(), mode="L")
#     145 if self.transform is not None:
# --> 146     img = self.transform(img)
#     148 if self.target_transform is not None:
#     149     target = self.target_transform(target)
#
# File d:\Anaconda\lib\site-packages\torchvision\transforms\transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File d:\Anaconda\lib\site-packages\torchvision\transforms\functional.py:174, in to_tensor(pic)
#     172 img = img.view(pic.size[1], pic.size[0], F_pil.get_image_num_channels(pic))
#     173 # put it from HWC to CHW format
# --> 174 img = img.permute((2, 0, 1)).contiguous()
#     175 if isinstance(img, torch.ByteTensor):
#     176     return img.to(dtype=default_float_dtype).div(255)
#
# KeyboardInterrupt:

# %%
plt.clf(); plt.cla() # clean
plt.plot(history['acc'], 'b', label='training acc')
plt.plot(history['val_acc'], 'r', label='val acc')
plt.title('Accuracy')
plt.legend()
plt.show()

# %%
plt.clf(); plt.cla() # clean
plt.plot(history['loss'], 'b', label='training loss')
plt.plot(history['val_loss'], 'r', label='val loss')
plt.title('Loss')
plt.legend()
plt.show()

# %% [markdown]
#  - 視覺化

# %%
true_label = []
pred_label = []
with torch.no_grad():
    for data in test_loader:
        img, label = data
        output = model(img).argmax(1)
        true_label.extend(label.numpy())
        pred_label.extend(output.numpy())

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
print('\033[33m' + 'Accuracy' + '\033[0m', accuracy_score(true_label, pred_label))
print('\033[33m' + 'Classification Report' + '\033[0m',
      classification_report(true_label, pred_label, target_names=test_data.classes), 
      sep='\n')
# Out:
# Accuracy 0.8408
# Classification Report
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.78      0.82      0.80      1000
#      Trouser       0.99      0.95      0.97      1000
#     Pullover       0.71      0.76      0.73      1000
#        Dress       0.82      0.88      0.85      1000
#         Coat       0.74      0.73      0.74      1000
#       Sandal       0.93      0.93      0.93      1000
#        Shirt       0.64      0.54      0.59      1000
#      Sneaker       0.94      0.90      0.92      1000
#          Bag       0.92      0.94      0.93      1000
#   Ankle boot       0.93      0.96      0.94      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(true_label, pred_label)
plt.cla(); plt.clf()
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=test_data.classes, yticklabels=test_data.classes)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Fashion-MNIST Confusion Matrix")
plt.show()

# %%
from torchsummary import summary
summary(model, (784, ))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                   [-1, 10]           7,850
# ================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.04
# ----------------------------------------------------------------
